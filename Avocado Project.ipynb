# %% [markdown]
# #                                                         Avocado Project
# ## Project Description
# This data was downloaded from the Hass Avocado Board website in May of 2018 & compiled into a single CSV.
#
# The table below represents weekly 2018 retail scan data for National retail volume (units) and price. Retail scan data comes directly from retailers’ cash registers based on actual retail sales of Hass avocados.
#
# Starting in 2013, the table below reflects an expanded, multi-outlet retail data set. Multi-outlet reporting includes an aggregation of the following channels: grocery, mass, club, drug, dollar and military. The Average Price (of avocados) in the table reflects a per unit (per avocado) cost, even when multiple units (avocados) are sold in bags.
#
# The Product Lookup codes (PLU’s) in the table are only for Hass avocados. Other varieties of avocados (e.g. greenskins) are not included in this table.
#
# Some relevant columns in the dataset:
# •	Date - The date of the observation
#
# •	AveragePrice - the average price of a single avocado
#
# •	type - conventional or organic
#
# •	year - the year
#
# •	Region - the city or region of the observation
#
# •	Total Volume - Total number of avocados sold
#
# •	4046 - Total number of avocados with PLU 4046 sold
#
# •	4225 - Total number of avocados with PLU 4225 sold
#
# •	4770 - Total number of avocados with PLU 4770 sold

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv(r"C:\Users\chaud\Downloads\avocado.csv")
df.head(10)
# Out:
#    Unnamed: 0        Date  AveragePrice  Total Volume     4046       4225  \
# 0           0  2015-12-27          1.33      64236.62  1036.74   54454.85
# 1           1  2015-12-20          1.35      54876.98   674.28   44638.81
# 2           2  2015-12-13          0.93     118220.22   794.70  109149.67
# 3           3  2015-12-06          1.08      78992.15  1132.00   71976.41
# 4           4  2015-11-29          1.28      51039.60   941.48   43838.39
# 5           5  2015-11-22          1.26      55979.78  1184.27   48067.99
# 6           6  2015-11-15          0.99      83453.76  1368.92   73672.72
# 7           7  2015-11-08          0.98     109428.33   703.75  101815.36
# 8           8  2015-11-01          1.02      99811.42  1022.15   87315.57
# 9           9  2015-10-25          1.07      74338.76   842.40   64757.44
#
#      4770  Total Bags  Small Bags  Large Bags  XLarge Bags          type  \
# 0   48.16     8696.87     8603.62       93.25          0.0  conventional
# ...

# %%
df.drop('Unnamed: 0',axis=1,inplace=True)

# %%
df.head(10)
# Out:
#          Date  AveragePrice  Total Volume     4046       4225    4770  \
# 0  2015-12-27          1.33      64236.62  1036.74   54454.85   48.16
# 1  2015-12-20          1.35      54876.98   674.28   44638.81   58.33
# 2  2015-12-13          0.93     118220.22   794.70  109149.67  130.50
# 3  2015-12-06          1.08      78992.15  1132.00   71976.41   72.58
# 4  2015-11-29          1.28      51039.60   941.48   43838.39   75.78
# 5  2015-11-22          1.26      55979.78  1184.27   48067.99   43.61
# 6  2015-11-15          0.99      83453.76  1368.92   73672.72   93.26
# 7  2015-11-08          0.98     109428.33   703.75  101815.36   80.00
# 8  2015-11-01          1.02      99811.42  1022.15   87315.57   85.34
# 9  2015-10-25          1.07      74338.76   842.40   64757.44  113.00
#
#    Total Bags  Small Bags  Large Bags  XLarge Bags          type  year  region
# 0     8696.87     8603.62       93.25          0.0  conventional  2015  Albany
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18249 entries, 0 to 18248
# Data columns (total 13 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Date          18249 non-null  object
#  1   AveragePrice  18249 non-null  float64
#  2   Total Volume  18249 non-null  float64
#  3   4046          18249 non-null  float64
#  4   4225          18249 non-null  float64
#  5   4770          18249 non-null  float64
#  6   Total Bags    18249 non-null  float64
#  7   Small Bags    18249 non-null  float64
#  8   Large Bags    18249 non-null  float64
#  9   XLarge Bags   18249 non-null  float64
#  10  type          18249 non-null  object
#  11  year          18249 non-null  int64
#  12  region        18249 non-null  object
# dtypes: float64(9), int64(1), object(3)
# memory usage: 1.8+ MB

# %% [markdown]
# - ##### There are 13 features in data.
# - ##### Date by default data type is object which need to change to datetime datatype.

# %%
df['Date']=pd.to_datetime(df.Date)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18249 entries, 0 to 18248
# Data columns (total 13 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Date          18249 non-null  datetime64[ns]
#  1   AveragePrice  18249 non-null  float64
#  2   Total Volume  18249 non-null  float64
#  3   4046          18249 non-null  float64
#  4   4225          18249 non-null  float64
#  5   4770          18249 non-null  float64
#  6   Total Bags    18249 non-null  float64
#  7   Small Bags    18249 non-null  float64
#  8   Large Bags    18249 non-null  float64
#  9   XLarge Bags   18249 non-null  float64
#  10  type          18249 non-null  object
#  11  year          18249 non-null  int64
#  12  region        18249 non-null  object
# dtypes: datetime64[ns](1), float64(9), int64(1), object(2)
# memory usage: 1.8+ MB

# %%
df.shape
# Out:
# (18249, 13)

# %%
df.isnull().sum()
# Out:
# Date            0
# AveragePrice    0
# Total Volume    0
# 4046            0
# 4225            0
# 4770            0
# Total Bags      0
# Small Bags      0
# Large Bags      0
# XLarge Bags     0
# type            0
# year            0
# region          0
# dtype: int64

# %% [markdown]
# - #### There is no null data in the dataset

# %%
df['type'].value_counts()
# Out:
# conventional    9126
# organic         9123
# Name: type, dtype: int64

# %%
df.describe().T
# Out:
#                 count           mean           std      min       25%  \
# AveragePrice  18249.0       1.405978  4.026766e-01     0.44      1.10
# Total Volume  18249.0  850644.013009  3.453545e+06    84.56  10838.58
# 4046          18249.0  293008.424531  1.264989e+06     0.00    854.07
# 4225          18249.0  295154.568356  1.204120e+06     0.00   3008.78
# 4770          18249.0   22839.735993  1.074641e+05     0.00      0.00
# Total Bags    18249.0  239639.202060  9.862424e+05     0.00   5088.64
# Small Bags    18249.0  182194.686696  7.461785e+05     0.00   2849.42
# Large Bags    18249.0   54338.088145  2.439660e+05     0.00    127.47
# XLarge Bags   18249.0    3106.426507  1.769289e+04     0.00      0.00
# year          18249.0    2016.147899  9.399385e-01  2015.00   2015.00
#
#                     50%        75%          max
# AveragePrice       1.37       1.66         3.25
# Total Volume  107376.76  432962.29  62505646.52
# 4046            8645.30  111020.20  22743616.17
# ...

# %%
df.median()
# Out:
# AveragePrice         1.37
# Total Volume    107376.76
# 4046              8645.30
# 4225             29061.02
# 4770               184.99
# Total Bags       39743.83
# Small Bags       26362.82
# Large Bags        2647.71
# XLarge Bags          0.00
# year              2016.00
# dtype: float64

# %% [markdown]
# - ##### We can easily suspect that some of the features contain outliers after looking at 50%, 75% and max columns.
# - ##### For most of columns have minimum value of zero.
# - ##### Almost in all columns value of mean is greater than median. Data is right skewed.

# %%
df.duplicated().sum()
# Out:
# 0

# %%
print(df['type'].unique())
# Out:
# ['conventional' 'organic']

# %%
df.groupby(['year','type'])['AveragePrice'].agg([min,max,np.mean,np.median])
# Out:
#                     min   max      mean  median
# year type
# 2015 conventional  0.49  1.59  1.077963    1.08
#      organic       0.81  2.79  1.673324    1.67
# 2016 conventional  0.51  2.20  1.105595    1.08
#      organic       0.58  3.25  1.571684    1.53
# 2017 conventional  0.46  2.22  1.294888    1.30
#      organic       0.44  3.17  1.735521    1.72
# 2018 conventional  0.56  1.74  1.127886    1.14
#      organic       1.01  2.30  1.567176    1.55

# %% [markdown]
# Comment :
#
# - Oraganic Avocado is 40-50% costlier than conventional avacado.
# - Avacodo got price hike in year 2017 as result of some reason may be inflation,shortage, more wages.
# - Except 2017 each year their is incresase in price of avacado.

# %%
df['Month']=pd.to_datetime(df['Date']).dt.month
df['day'] = pd.to_datetime(df['Date']).dt.day
df
# Out:
#             Date  AveragePrice  Total Volume     4046       4225    4770  \
# 0     2015-12-27          1.33      64236.62  1036.74   54454.85   48.16
# 1     2015-12-20          1.35      54876.98   674.28   44638.81   58.33
# 2     2015-12-13          0.93     118220.22   794.70  109149.67  130.50
# 3     2015-12-06          1.08      78992.15  1132.00   71976.41   72.58
# 4     2015-11-29          1.28      51039.60   941.48   43838.39   75.78
# ...          ...           ...           ...      ...        ...     ...
# 18244 2018-02-04          1.63      17074.83  2046.96    1529.20    0.00
# 18245 2018-01-28          1.71      13888.04  1191.70    3431.50    0.00
# 18246 2018-01-21          1.87      13766.76  1191.92    2452.79  727.94
# 18247 2018-01-14          1.93      16205.22  1527.63    2981.04  727.01
# 18248 2018-01-07          1.62      17489.58  2894.77    2356.13  224.53
#
#        Total Bags  Small Bags  Large Bags  XLarge Bags  type  year  region  \
# ...

# %%
df.drop('Date',axis=1,inplace=True)

# %%
df
# Out:
#        AveragePrice  Total Volume     4046       4225    4770  Total Bags  \
# 0              1.33      64236.62  1036.74   54454.85   48.16     8696.87
# 1              1.35      54876.98   674.28   44638.81   58.33     9505.56
# 2              0.93     118220.22   794.70  109149.67  130.50     8145.35
# 3              1.08      78992.15  1132.00   71976.41   72.58     5811.16
# 4              1.28      51039.60   941.48   43838.39   75.78     6183.95
# ...             ...           ...      ...        ...     ...         ...
# 18244          1.63      17074.83  2046.96    1529.20    0.00    13498.67
# 18245          1.71      13888.04  1191.70    3431.50    0.00     9264.84
# 18246          1.87      13766.76  1191.92    2452.79  727.94     9394.11
# 18247          1.93      16205.22  1527.63    2981.04  727.01    10969.54
# 18248          1.62      17489.58  2894.77    2356.13  224.53    12014.15
#
#        Small Bags  Large Bags  XLarge Bags  type  year  region  Month  day
# ...

# %%
plt.figure(figsize=(20,8))
sns.heatmap(df.describe(),linewidths = 0.1,fmt='0.1f',annot = True,cmap='PiYG')
# Out:
# <Axes: >

# %%
sns.countplot(df, x= 'type')
# Out:
# <Axes: xlabel='type', ylabel='count'>

# %%
df

# %%
df['type'].value_counts()
# Out:
# conventional    9126
# organic         9123
# Name: type, dtype: int64

# %% [markdown]
# - From the above countplot and values target variable data looks balanced

# %%
df['year'].value_counts()
# Out:
# 2017    5722
# 2016    5616
# 2015    5615
# 2018    1296
# Name: year, dtype: int64

# %%
sns.set_palette("Set2")
sns.countplot(df, x= 'year')
# Out:
# <Axes: xlabel='year', ylabel='count'>

# %% [markdown]
# - This dataset contain data from 2015 to 2018
# *  Maximum sales entry belongs to year 2017 while very few sales entry comes from 2018.

# %% [markdown]
# ### Bivariate Analysis

# %%
plt.figure(figsize=(8,6))
sns.catplot(y="AveragePrice", x="type", data=df, kind="boxen", palette = 'PuRd')

# %% [markdown]
# - We can see that Average Price of Organic Avocado is higher than Conventional Avocado.

# %%
plt.figure(figsize=(15,6))
sns.barplot(x=df['region'],y=df['AveragePrice'], data=df)
plt.title(f'Bar Plot for regions')
plt.xticks(rotation=90)
plt.show()

# %%
sns.catplot(x = "year", y = "Total Volume", kind="strip",data=df,height=8, linewidth=2, aspect=2.)

# %%
plt.figure(figsize=(15,13))
sns.pointplot(x = "Total Volume", y = "region" ,data=df)
# Out:
# <Axes: xlabel='Total Volume', ylabel='region'>

# %%
plt.figure(figsize=(15,7))
sns.barplot(x="year", y="AveragePrice", hue='type', data=df)
plt.show()

# %%
df2= df.copy()

# %%
df2.drop(['type','region','year'], axis=1, inplace=True)

# %%
plt.figure(figsize=(20,25), facecolor='wheat')
plot_number=1

for column in df2:
    if plot_number <= 9:
        ax=plt.subplot(6,3, plot_number)
        sns.distplot(df2[column], color='green')
        plt.xlabel(column, fontsize=20)

    plot_number+=1

plt.show()

# %% [markdown]
# Comment :
# - We can see skewed data with presence of outliers with sharp peak.
# - Most of the plots are right skewed, having value of mean very small compare to std. deviation & median. This is resulting in sharp high peak.Very few data points are present as we move away from zero to other end of x-axis.

# %% [markdown]
# ### Encoding categorical data

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
df['region']=le.fit_transform(df['region'])
df['type']=le.fit_transform(df['type'])
df.head()
# Out:
#    AveragePrice  Total Volume     4046       4225    4770  Total Bags  \
# 0          1.33      64236.62  1036.74   54454.85   48.16     8696.87
# 1          1.35      54876.98   674.28   44638.81   58.33     9505.56
# 2          0.93     118220.22   794.70  109149.67  130.50     8145.35
# 3          1.08      78992.15  1132.00   71976.41   72.58     5811.16
# 4          1.28      51039.60   941.48   43838.39   75.78     6183.95
#
#    Small Bags  Large Bags  XLarge Bags  type  year  region  Month  day
# 0     8603.62       93.25          0.0     0  2015       0     12   27
# 1     9408.07       97.49          0.0     0  2015       0     12   20
# 2     8042.21      103.14          0.0     0  2015       0     12   13
# 3     5677.40      133.76          0.0     0  2015       0     12    6
# 4     5986.26      197.69          0.0     0  2015       0     11   29

# %% [markdown]
# ### Outliers Detection and Removal

# %%
plt.figure(figsize=(20,20), facecolor='cyan')
plot_number=1

for column in df:
    if plot_number <= 15:
        ax=plt.subplot(5,3, plot_number)
        sns.boxplot(df[column], color='pink')
        plt.xlabel(column, fontsize=20)

    plot_number+=1
plt.tight_layout()
plt.show()

# %% [markdown]
# #### Comment -
# - we can see that there is Outliers in ['AveragePrice', 'Total Volume', '4046', '4225', '4770', 'Total Bags','Small Bags', 'Large Bags', 'XLarge Bags']

# %%
from scipy.stats import zscore
z = np.abs(zscore(df))
threshold = 3
df1 = df[(z<3).all(axis = 1)]

# %%
print('Shape of dataset after removing outliers :', df1.shape)
# Out:
# Shape of dataset after removing outliers : (17651, 14)

# %%
plt.figure(figsize=(14,10))
sns.heatmap(df1.corr().T,linewidth=0.3,fmt='0.3f' ,annot=True, cmap= 'coolwarm')
# Out:
# <Axes: >

# %%
plt.figure(figsize = (18,6))
df1.corr()['AveragePrice'].drop(['AveragePrice']).plot(kind='bar',color = 'c')
plt.xlabel('Features',fontsize=15)
plt.ylabel('AveragePrice',fontsize=15)
plt.title('Correlation of features with Target Variable Average Price',fontsize = 18)
plt.show()

# %% [markdown]
# #### Comment-
# - we can observe the correlation of Dataset through heatmap and bar chart.
#
#   'type', 'year','region' and 'day' are positively correlated with target column and rest of the columns have negative       corelation to column (Average   Price) .

# %% [markdown]
# ### Checking multicollinearity using Varience-inflation-factor (VIF)

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor
vif= pd.DataFrame()
vif['VIF']= [variance_inflation_factor(df1.values,i) for i in range(df1.shape[1])]
vif['Features']= df1.columns
vif
# Out:
#              VIF      Features
# 0   2.499139e+01  AveragePrice
# 1   4.977395e+08  Total Volume
# 2   8.727666e+07          4046
# 3   7.504348e+07          4225
# 4   5.281429e+05          4770
# 5   2.333471e+13    Total Bags
# 6   1.518921e+13    Small Bags
# 7   1.478286e+12    Large Bags
# 8   7.092970e+09   XLarge Bags
# 9   3.729001e+00          type
# 10  2.542391e+01          year
# 11  4.114701e+00        region
# 12  4.218813e+00         Month
# 13  4.203526e+00           day

# %% [markdown]
# #### Comment
# - Dropping columns  4046,4225,4770 as they shows multicollinearity
# -  4046,4225,4770 are shows multicollinearity. These feature are nothing but Total avacado sold under particular grade,
#    which are already counted in Total Volume. As we do not have any price data according each grade of avacado.
#    These feature doesnot have any meaning in ML model.So gone drop them.
# - Same goes with Total bags. Total bags is sum of all other type of bags. We gone keep drop Total bags and going to keep other differnt size bags counts features.
# - Next is region feature, we also going drop this as it very poorly correlated with other features.

# %%
df1.drop(columns=['4046','4225','4770','region','Total Bags'],axis=1, inplace=True)

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor
vif= pd.DataFrame()
vif['VIF']= [variance_inflation_factor(df1.values,i) for i in range(df1.shape[1])]
vif['Features']= df1.columns
vif
# Out:
#          VIF      Features
# 0  24.391455  AveragePrice
# 1   7.757550  Total Volume
# 2   7.710177    Small Bags
# 3   1.970398    Large Bags
# 4   1.693501   XLarge Bags
# 5   3.645412          type
# 6  22.611895          year
# 7   4.212371         Month
# 8   4.202555           day

# %% [markdown]
# - We will drop year as it is highly correlated

# %%
df1.drop(columns=['year'],axis=1, inplace=True)

# %%
df1.shape
# Out:
# (17651, 8)

# %% [markdown]
# ### Checking Skewness

# %%
df1.skew()
# Out:
# AveragePrice    0.377432
# Total Volume    3.767138
# Small Bags      4.222706
# Large Bags      5.053434
# XLarge Bags     6.135607
# type           -0.037741
# Month           0.107408
# day             0.011778
# dtype: float64

# %% [markdown]
# ### Removing Skewness

# %%
for col in df1.columns:
    if df1.skew().loc[col]>0.55:
        df1[col]=np.log1p(df1[col])

# %%
df1.shape
# Out:
# (17651, 8)

# %% [markdown]
# ### Standard Scaling

# %%
X = df1.drop('AveragePrice', axis=1)
Y = df1['AveragePrice']

# %%
from sklearn.preprocessing import StandardScaler
scaler= StandardScaler()
X_scale = scaler.fit_transform(X)

# %%
X.shape
# Out:
# (17651, 7)

# %%
Y.shape
# Out:
# (17651,)

# %%
Y.value_counts()
# Out:
# 1.15    193
# 1.18    191
# 1.26    189
# 1.59    186
# 1.48    185
#        ...
# 2.60      2
# 0.49      2
# 0.46      1
# 0.44      1
# 0.48      1
# Name: AveragePrice, Length: 215, dtype: int64

# %% [markdown]
# ### Machine Learning

# %%
from sklearn.linear_model import LinearRegression
from sklearn.ensemble import RandomForestRegressor
from sklearn.tree import DecisionTreeRegressor
from sklearn.svm import SVR
from sklearn.ensemble import AdaBoostRegressor
from sklearn.ensemble import  GradientBoostingRegressor
from sklearn.neighbors import KNeighborsRegressor
from sklearn.metrics import mean_squared_error, mean_absolute_error
from sklearn.metrics import r2_score, confusion_matrix
from sklearn.model_selection import train_test_split
from sklearn.linear_model import  Ridge
from sklearn.linear_model import  Lasso
from sklearn.metrics import accuracy_score, confusion_matrix,classification_report,f1_score
from sklearn.model_selection import cross_val_score

# %%
X_train, X_test, Y_train, Y_test = train_test_split(X_scale, Y, random_state=42, test_size=.33)
print('Training feature matrix size:',X_train.shape)
print('Training target vector size:',Y_train.shape)
print('Test feature matrix size:',X_test.shape)
print('Test target vector size:',Y_test.shape)
# Out:
# Training feature matrix size: (11826, 7)
# Training target vector size: (11826,)
# Test feature matrix size: (5825, 7)
# Test target vector size: (5825,)

# %%
maxR2_score=0
maxRS=0
for i in range(0,200):
    X_train, X_test, y_train, y_test = train_test_split(X_scale, Y, random_state=i, test_size=.33)
    lr= LinearRegression()
    lr.fit(X_train,y_train)
    y_pred=lr.predict(X_test)
    R2=r2_score(y_test,y_pred)
    if R2>maxR2_score:
        maxR2_score=R2
        maxRS=i
        
print('Best R2 Score is: ', maxR2_score,'\nAt Random State: ', maxRS)
# Out:
# Best R2 Score is:  0.4657283356383638
# At Random State:  108

# %%
X_train,X_test,Y_train,Y_test = train_test_split(X,Y,test_size = 0.33, random_state=maxRS)
lr = LinearRegression()
lr.fit(X_train,Y_train)
pred = lr.predict(X_test)
print('Predicted result :\n', pred)
print('\n')
print('actual result\n',Y_test)
# Out:
# Predicted result :
#  [1.27401198 1.34864051 1.81904272 ... 1.77105893 1.43738952 1.19528467]
#
#
# actual result
#  4167     1.31
# 3695     1.54
# 9334     1.48
# 5987     0.93
# 14679    0.96
#          ...
# 12186    1.59
# 9951     1.65
# 11263    1.85
# 5361     1.61
# 6108     1.79
# Name: AveragePrice, Length: 5825, dtype: float64

# %%
print('\033[1m'+' Error :'+'\033[0m')
print('Mean absolute error :', mean_absolute_error(Y_test,pred))
print('Mean squared error :', mean_squared_error(Y_test,pred))
print('Root Mean Squared Error:', np.sqrt(mean_squared_error(Y_test,pred)))
print('\n')
from sklearn.metrics import r2_score
print('\033[1m'+' R2 Score :'+'\033[0m')
print(r2_score(Y_test,pred))
# Out:
#  Error :
# Mean absolute error : 0.2244341314254543
# Mean squared error : 0.08038030238303712
# Root Mean Squared Error: 0.2835142013780564
#
#
#  R2 Score :
# 0.4657283356383638

# %%
rf = RandomForestRegressor(n_estimators = 70 ,max_depth=25)
dtc = DecisionTreeRegressor()
adb=AdaBoostRegressor(learning_rate=0.1)
gradb=GradientBoostingRegressor(max_depth=25,learning_rate=0.1)
rd=Ridge(alpha=0.01)
model = [rf,rd,dtc,adb,gradb]

for m in model:
    m.fit(X_train,Y_train)
    m.score(X_train,Y_train)
    y_pred = m.predict(X_test)
    print('\n')                                        
    print('\033[1m'+' Error of ', m, ':' +'\033[0m')
    print('Mean absolute error :', mean_absolute_error(Y_test,y_pred))
    print('Mean squared error :', mean_squared_error(Y_test,y_pred))
    print('Root Mean Squared Error:', np.sqrt(mean_squared_error(Y_test,y_pred)))
    print('\n')

    print('\033[1m'+' R2 Score :'+'\033[0m')
    print(r2_score(Y_test,y_pred)) 
    print('=====================================================================================================')
# Out:
#  Error of  RandomForestRegressor(max_depth=25, n_estimators=70) :
# Mean absolute error : 0.16319512775953954
# Mean squared error : 0.04759459722865729
# Root Mean Squared Error: 0.21816186016042605
#
#
#  R2 Score :
# 0.6836483078304183
# ...
#
#
#  Error of  Ridge(alpha=0.01) :
# Mean absolute error : 0.22443418854074643
# Mean squared error : 0.08038032644619475
# Root Mean Squared Error: 0.28351424381535884
#
#
#  R2 Score :
# 0.46572817569540625
# ...
#
#
#  Error of  DecisionTreeRegressor() :
# Mean absolute error : 0.21913476394849787
# Mean squared error : 0.09496727896995708
# Root Mean Squared Error: 0.30816761505706125
#
#
#  R2 Score :
# 0.36877164316462885
# ...
#
#
#  Error of  AdaBoostRegressor(learning_rate=0.1) :
# Mean absolute error : 0.22434791820073796
# Mean squared error : 0.07770517083193001
# Root Mean Squared Error: 0.2787564722691296
#
#
#  R2 Score :
# 0.48350939572178453
# ...
#
#
#  Error of  GradientBoostingRegressor(max_depth=25) :
# ...

# %%
model = [rf,rd,dtc,adb,gradb]

for m in model:
    score = cross_val_score(m, X_scale, Y, cv =5)
    print('\n')
    print('\033[1m'+'Cross Validation Score :',m,":"+'\033[0m\n')
    print("Mean CV Score :",score.mean())
    print('==============================================================================================================')
# Out:
# Cross Validation Score : RandomForestRegressor(max_depth=25, n_estimators=70) :
#
# Mean CV Score : -0.15191304087388058
# ...
#
#
# Cross Validation Score : Ridge(alpha=0.01) :
#
# Mean CV Score : -0.01237094060113204
# ...
#
#
# Cross Validation Score : DecisionTreeRegressor() :
#
# Mean CV Score : -0.810279394820961
# ...
#
#
# Cross Validation Score : AdaBoostRegressor(learning_rate=0.1) :
#
# Mean CV Score : -0.03123124411540592
# ...
#
#
# Cross Validation Score : GradientBoostingRegressor(max_depth=25) :
#
# Mean CV Score : -0.7166358480600945
# ...

# %% [markdown]
# ##### Among all Model Random Forest Regressor gave us maximum R2 score of 0.683648 and minimum RMSE value of 0.2181.

# %%
prediction_=pd.DataFrame({'predicted values':y_pred,'actual values':Y_test})
prediction_
# Out:
#        predicted values  actual values
# 4167           1.568197           1.31
# 3695           1.250487           1.54
# 9334           1.328612           1.48
# 5987           0.844926           0.93
# 14679          0.990011           0.96
# ...                 ...            ...
# 12186          1.397888           1.59
# 9951           1.114659           1.65
# 11263          1.495260           1.85
# 5361           1.503185           1.61
# 6108           1.759762           1.79
#
# [5825 rows x 2 columns]

# %%
plt.figure(figsize=(12,7))
plt.scatter(y_pred,y_test, c='g')
plt.yscale('log')
plt.xscale('log')
plt1 = max(max(y_pred), max(Y_test))
plt2 = min(min(y_pred), min(Y_test))
plt.plot([plt1, plt2], [plt1, plt2], 'b-')
plt.xlabel('Actual Values', fontsize=15)
plt.ylabel('Predicted Values', fontsize=15)
plt.title("Random Forest Regressor")
plt.show()

# %%
g=plt.scatter(Y_test, y_pred)
g.axes.set_yscale('log')
g.axes.set_xscale('log')
g.axes.set_xlabel('True Values ')
g.axes.set_ylabel('Predictions ')
g.axes.axis('equal')
g.axes.axis('square')
# Out:
# (0.40252539508294255,
#  2.8529876972442096,
#  0.4412268998323852,
#  2.8916892019936524)

# %%
import joblib
joblib.dump(model,'avocado_model.joblib')
# Out:
# ['avocado_model.joblib']
